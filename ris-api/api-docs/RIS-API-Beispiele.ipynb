# %% [markdown]
# # Python-Beispiele für RIS-API
#
# This notebook contains some examples to show how to work with the RIS API.
# Dieses Notebook beinhaltet einige Python-Beispiele, die zeigen, wie man mit der RIS-API arbeiten kann.
#
# Inhaltsverzeichnis:
#
# 1. [Mitglieder einer Partei](#Mitglieder-einer-Partei)
# 1. [Gemeinderats-Geschäfte](#Gemeinderats-Geschäfte)

# %%
import requests
from pprint import pprint
import pandas as pd
import random

# %% [markdown]
# ## Mitglieder einer Partei
#
# Um alle Mitglieder einer Partei zu bekommen, müssen folgende Abfragen gemacht werden:
#
#     1. ID der Partei holen
#     1. Suche nach Mitgliedern der Partei (mit dieser ID)
#     1. *Optional:* Detail-Informationen eines Mitglieds holen

# %% [markdown]
# ### Alle Parameter holen

# %%
headers = {'Accept': 'application/json'}
r = requests.get('https://www.gemeinderat-zuerich.ch/api/Mitglieder/parameter', headers=headers)
params = r.json()

# %%
# get id of random party
parties = params['Parteien']
party = random.choice(parties)
party

# %% [markdown]
# ### Mitglieder der Partei abfragen

# %%
query = {'parteiId': party['Id']}
headers = {'Accept': 'application/json'}
r = requests.get('https://www.gemeinderat-zuerich.ch/api/Mitglieder/suchen', params=query, headers=headers)
members = r.json()
members
# Out:
# [{'Id': 'afb2e0bc-b941-4fa4-8936-9b4978fc1ee1',
#   'Name': 'Akyol',
#   'Vorname': 'Ezgi',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': '4 und 5',
#   'WahlkreisOrderBy': 102},
#  {'Id': 'ee8204f4-9290-49ca-99ae-d18a22a0a513',
#   'Name': 'Angst',
#   'Vorname': 'Walter',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': ' 3',
#   'WahlkreisOrderBy': 101},
#  {'Id': 'bbfb8ca0-91b1-448d-b1fc-c5e3bb35c158',
#   'Name': 'Eberle',
#   'Vorname': 'Natalie',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': ' 3',
#   'WahlkreisOrderBy': 101},
#  {'Id': '4a1be35e-3f69-48a4-85b1-3fee07b006ae',
#   'Name': 'Garcia Nuñez',
#   'Vorname': 'David',
#   'Titel': 'Dr.',
#   'Partei': 'AL',
#   'Wahlkreis': '4 und 5',
#   'WahlkreisOrderBy': 102},
#  {'Id': 'b84bdf09-0197-4eac-989f-b6e49b297edd',
#   'Name': 'Kirstein',
#   'Vorname': 'Andreas',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': '11',
#   'WahlkreisOrderBy': 107},
#  {'Id': '7f22b482-38d0-43ca-9599-a71f3edcbd73',
#   'Name': 'Leitner Verhoeven',
#   'Vorname': 'Andrea',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': '10',
#   'WahlkreisOrderBy': 106},
#  {'Id': '9e46c2e0-626a-4d19-82e8-de1b2a3e216d',
#   'Name': 'Maillard',
#   'Vorname': 'Patrik',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': ' 6',
#   'WahlkreisOrderBy': 103},
#  {'Id': 'ad19c2cb-10d3-426a-a915-45763615ca0c',
#   'Name': 'Romanelli',
#   'Vorname': 'Olivia',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': '1 und 2',
#   'WahlkreisOrderBy': 100},
#  {'Id': 'd2faaa00-3795-451c-9f72-1d17ebee399b',
#   'Name': 'Schiller',
#   'Vorname': 'Christina',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': ' 9',
#   'WahlkreisOrderBy': 105},
#  {'Id': 'ddcd41f6-9873-4002-80d8-dfd87114c9a5',
#   'Name': 'Schiwow',
#   'Vorname': 'Mischa',
#   'Titel': None,
#   'Partei': 'AL',
#   'Wahlkreis': '7 und 8',
#   'WahlkreisOrderBy': 104}]

# %% [markdown]
# ### Details der Mitglieder abfragen
#
# Mit dem `/Mitglieder/details` Endpunkt können Details eines Mitglieds abgefragt werden:

# %%
def get_member_details(member):
    query = {'mid': member['Id']}
    headers = {'Accept': 'application/json'}
    r = requests.get('https://www.gemeinderat-zuerich.ch/api/Mitglieder/details', params=query, headers=headers)
    details = r.json()
    # trim "Wahlkreis" and "Wohnkreis" since they have a padding
    details['Wahlkreis'] = details['Wahlkreis'].strip()
    if details['Wohnkreis']:
        details['Wohnkreis'] = details['Wohnkreis'].strip()
    # add original member to keep WahlkreisOrderBy column
    details.update(member)
    return details
    
member_details = [get_member_details(m) for m in members]
df = pd.DataFrame(member_details)
df
# Out:
#                                             Adressen Anrede  \
# 0  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Frau
# 1  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Herr
# 2  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Frau
# 3  [{'Addressart': 'Postadresse', 'Strasse1': '',...   Herr
# 4  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Herr
# 5  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Frau
# 6  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Herr
# 7  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Frau
# 8  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Frau
# 9  [{'Addressart': 'Postadresse', 'Strasse1': Non...   Herr
#
#                                         Beruf          EmailGeschaeftlich  \
# 0                                   Studentin                        None
# 1                        Leiter Kommunikation       walterangst@gmail.com
# 2                 Soziale Quartierentwicklung         quartiernetz@qnf.ch
# 3                                        Arzt       david.garcia@al-zh.ch
# 4                    Stv. Bibliotheksdirektor
# 5  Berufsschullehrerin, Leiterin Bildungsgang
# 6                            Koch, Journalist
# 7                          Pädagogin, Imkerin                        None
# 8                                   Studentin                        None
# 9                         Filmwissenschaftler  micha.schiwow@prochaine.ch
#
#                      EmailPrivat Fraktion           Geburtstag  \
# 0              ezgi.akyol@gmx.ch       AL  1986-09-11T00:00:00
# 1                           None       AL  1961-09-22T00:00:00
# 2                                      AL  1967-04-24T00:00:00
# 3                                      AL  1975-05-16T00:00:00
# 4            andreas@kirstein.ch       AL  1963-05-08T00:00:00
# 5           acaleitner@gmail.com       AL  1964-07-21T00:00:00
# 6            paedemail@yahoo.com       AL  1965-06-07T00:00:00
# 7            olivia@romanelli.ch       AL  1974-12-09T00:00:00
# 8  christina.schiller@bluewin.ch       AL  1989-06-04T00:00:00
# 9                mschiwow@gmx.ch       AL  1961-08-31T00:00:00
#
#                              GruppenMitgliedschaften  \
# 0  [{'Von': '2014-05-07T00:00:00', 'Bis': None, '...
# 1  [{'Von': '2002-04-10T00:00:00', 'Bis': None, '...
# 2  [{'Von': '2018-05-16T00:00:00', 'Bis': None, '...
# 3  [{'Von': '2017-01-19T00:00:00', 'Bis': None, '...
# 4  [{'Von': '2012-07-12T00:00:00', 'Bis': None, '...
# 5  [{'Von': '2013-05-29T00:00:00', 'Bis': None, '...
# 6  [{'Von': '2019-01-25T00:00:00', 'Bis': None, '...
# 7  [{'Von': '2019-02-11T00:00:00', 'Bis': None, '...
# 8  [{'Von': '2014-05-07T00:00:00', 'Bis': None, '...
# 9  [{'Von': '2016-06-28T00:00:00', 'Bis': None, '...
#
#                                      Id  \
# 0  afb2e0bc-b941-4fa4-8936-9b4978fc1ee1
# 1  ee8204f4-9290-49ca-99ae-d18a22a0a513
# 2  bbfb8ca0-91b1-448d-b1fc-c5e3bb35c158
# 3  4a1be35e-3f69-48a4-85b1-3fee07b006ae
# 4  b84bdf09-0197-4eac-989f-b6e49b297edd
# 5  7f22b482-38d0-43ca-9599-a71f3edcbd73
# 6  9e46c2e0-626a-4d19-82e8-de1b2a3e216d
# 7  ad19c2cb-10d3-426a-a915-45763615ca0c
# 8  d2faaa00-3795-451c-9f72-1d17ebee399b
# 9  ddcd41f6-9873-4002-80d8-dfd87114c9a5
#
#                               Interessenverbindungen  ...  \
# 0                                               None  ...
# 1  - Mieterinnen– und Mieterverband Zürich, Leite...  ...
# 2         - Quartiernetz Friesenberg, Stellenleitung  ...
# 3     - Volkshaus Zürich, Mitglied des Stiftungsrats  ...
# 4  - Allg. Baugenossenschaft Zürich, Zürich, Vize...  ...
# 5  - Stiftung Wohnungen für kinderreiche Familien...  ...
# 6  - Quartierverein Wipkingen, Vorstand, Ressort ...  ...
# 7  - BienenSchweiz, Sektion ZH 101, Betriebsberat...  ...
# 8  VI Holding, Verwaltungsratsmitglied\r- Fondazi...  ...
# 9  - Verein Roadmovie Lausanne, Mitglied des Vors...  ...
#
#                       NameInUrl Partei Sitznummer TelefonGeschaeftlich  \
# 0                  Ezgi%20Akyol     AL       None                 None
# 1                Walter%20Angst     AL       None        044 296 90 30
# 2              Natalie%20Eberle     AL       None        043 537 80 17
# 3   David%20Garcia%20Nu%c3%b1ez     AL       None
# 4            Andreas%20Kirstein     AL       None
# 5  Andrea%20Leitner%20Verhoeven     AL       None                 None
# 6             Patrik%20Maillard     AL       None
# 7            Olivia%20Romanelli     AL       None                 None
# 8          Christina%20Schiller     AL       None                 None
# 9              Mischa%20Schiwow     AL       None        044 488 44 25
#
#    TelefonPrivat Titel    Vorname Wahlkreis WahlkreisOrderBy Wohnkreis
# 0           None  None       Ezgi   4 und 5              102         4
# 1           None  None     Walter         3              101         3
# 2                 None    Natalie         3              101         9
# 3                  Dr.      David   4 und 5              102         1
# 4                 None    Andreas        11              107        11
# 5                 None     Andrea        10              106        10
# 6                 None     Patrik         6              103        10
# 7                 None     Olivia   1 und 2              100         2
# 8           None  None  Christina         9              105         9
# 9  044 262 60 23  None     Mischa   7 und 8              104         7
#
# [10 rows x 24 columns]

# %% [markdown]
# ### Diagramm aller Mitglieder einer Partei nach Wahlkreis

# %%
count_by_wahlkreis = df[['Wahlkreis', 'WahlkreisOrderBy']].groupby(['Wahlkreis', 'WahlkreisOrderBy']).size().reset_index(name='Anzahl')
count_by_wahlkreis = count_by_wahlkreis.sort_values(by=['WahlkreisOrderBy'])
count_by_wahlkreis.plot.bar(x='Wahlkreis', y='Anzahl')

# %% [markdown]
# ## Gemeinderats-Geschäfte
