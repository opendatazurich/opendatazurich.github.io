# %%
import os
import sys
import re
import datetime
import traceback
import pytz
import math
import json
import csv
import chardet
from pprint import pprint
import difflib
from wasabi import color
import requests
from ckanapi import RemoteCKAN, NotFound
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %%
#__location__ = os.path.realpath(
#    os.path.join(
#        os.getcwd(),
#        os.path.dirname(__file__)
#    )
#)
__location__ = os.path.abspath('')

# %%
requests_kwargs = {"verify": False}

# %%
def convert_attributes(json_attr):
    # insert attributes
    try:
        attributes = json.loads(json_attr)
    except json.decoder.JSONDecodeError as e:
        print(f"Error: {e}", file=sys.stderr)
        attributes = []
    attrs = []
    for attribute in attributes:
        m = re.match(
            r"^(?P<name>.+?)(\s*\(technisch: (?P<tech_name>.+?)\))?$", attribute[0]
        )
        assert m, f"Could not match name and tech_name from {attribute[0]}"
        attr = {
            "description": attribute[1],
            "name": m["name"],
            "tech_name": m["tech_name"],
        }
        attrs.append(attr)
    return attrs

def get_csv_attributes(urls):
    # use the first URL
    partial_path = os.path.join(__location__, 'partial.csv')
    download_partial_csv(urls[0], partial_path)

    partial_rows = rows_from_csv(partial_path, delimiter=',')
    return list(partial_rows[0].keys())

def download_partial_csv(url, path):
    remote = requests.Session()
    remote.verify = False # do not verify SSL certs

    r = remote.get(url)
    with open(path, 'wb') as f:
        # break after some chunks
        total_chunks = 10
        for chunk in r.iter_content(1024):
            f.write(chunk)

            total_chunks -= 1
            if total_chunks == 0:
                break

def rows_from_csv(input_file, delimiter=';', input_encoding='detect'):
    if input_encoding == 'detect':
        input_encoding = _detect_file_encoding(input_file)

    with open(input_file, 'r', encoding=input_encoding) as f:
        # if a list of delimiters is given, try to sniff the correct one
        if isinstance(delimiter, list):
            dialect = csv.Sniffer().sniff(f.read(), delimiter)
            f.seek(0)
            reader = csv.DictReader(f, dialect=dialect)
        else:
            reader = csv.DictReader(f, delimiter=delimiter)
        rows = [r for r in reader]
    return rows


def _detect_file_encoding(input_file, line_count=20):
    with open(input_file, 'rb') as f:
        # read some lines
         rawdata = b''.join([f.readline() for _ in range(line_count)])
    return chardet.detect(rawdata)['encoding']

def diff_strings(a, b):
    output = []
    matcher = difflib.SequenceMatcher(None, a, b)
    changed = False
    for opcode, a0, a1, b0, b1 in matcher.get_opcodes():
        if opcode == "equal":
            output.append(a[a0:a1])
        elif opcode == "insert":
            changed = True
            output.append(color(b[b0:b1], fg=16, bg="green"))
        elif opcode == "delete":
            changed = True
            output.append(color(a[a0:a1], fg=16, bg="red"))
        elif opcode == "replace":
            changed = True
            output.append(color(b[b0:b1], fg=16, bg="green"))
            output.append(color(a[a0:a1], fg=16, bg="red"))

    if not changed:
        return ""

    return "".join(output)

# %%
BASE_URL = os.getenv('CKAN_BASE_URL')
API_KEY = os.getenv('CKAN_API_KEY')
ckan = RemoteCKAN(BASE_URL, apikey=API_KEY)

# %%
BASE_URL
# Out:
# 'https://data.integ.stadt-zuerich.ch'

# %%
# pagination
more_results = True
max_rows = 10
start = 0

rows = []
while(more_results):  
    results = ckan.call_action(
        "package_search", {"q": "res_format:csv -tags:geodaten", "start": start, "rows": max_rows}, requests_kwargs=requests_kwargs
    )
    start += max_rows
    more_results = False
    if start > results['count']:
        more_results = False

    for dataset in results["results"]:
        pprint(dataset)
        ckan_attributes = convert_attributes(dataset['sszFields'])
        csv_attributes = get_csv_attributes([r['url'] for r in dataset['resources'] if r['format'].lower() == 'csv'])
        #pprint(csv_attributes)

        row = {
            "author": dataset["author"],
            "dataset_name": dataset['name'],
            "dataset_title": dataset['title'],
            "ckan_attributes": json.dumps([a['tech_name'] or a['name'] for a in ckan_attributes]),
            "csv_attributes": json.dumps(csv_attributes),
        }
        rows.append(row)
rows
# Out:
# c:\Users\sszods\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.szh.loc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'author': 'Dienstabteilung Verkehr, Sicherheitsdepartement',
#  'author_email': None,
#  'creator_user_id': 'd2e1adfa-4bdb-4022-a3b9-6d56ffbb9f31',
#  'dataQuality': 'Siehe Bemerkungen',
#  'dataType': ['Einzeldaten'],
#  'dateFirstPublished': '13.03.2020',
#  'dateLastUpdated': '29.11.2022',
#  'extras': [{'key': 'harvest_object_id',
#              'value': 'b85e5a43-157f-46d4-95d1-ffc2dbbf9df8'},
#             {'key': 'harvest_source_id',
#              'value': 'cc11cf5d-747f-4a65-a0a2-7786b99e3c76'},
#             {'key': 'harvest_source_title',
#              'value': 'INT_DWH Dropzone Harvester'}],
#  'groups': [{'description': '',
#              'display_name': 'Mobilität',
#              'id': 'mobilitat',
#              'image_display_url': 'https://statistik.stadt-zuerich.ch/Modules/ogd_bspe/group_pics/kategorien-12.png',
#              'name': 'mobilitat',
#              'title': 'Mobilität'},
#             {'description': '',
#              'display_name': 'Umwelt',
#              'id': 'umwelt',
#              'image_display_url': 'https://statistik.stadt-zuerich.ch/Modules/ogd_bspe/group_pics/kategorien-17.png',
#              'name': 'umwelt',
#              'title': 'Umwelt'}],
#  'id': '1ed324d3-9659-43ca-a330-6780fef24d99',
#  'isopen': True,
#  'legalInformation': '',
#  'license_id': 'cc-zero',
#  'license_title': 'Creative Commons CCZero',
#  'license_url': 'http://www.opendefinition.org/licenses/cc-zero',
#  'maintainer': 'Open Data Zürich',
#  'maintainer_email': 'opendata@zuerich.ch',
#  'metadata_created': '2022-01-20T08:50:37.622516',
#  'metadata_modified': '2022-11-28T23:36:42.085258',
#  'name': 'int_dwh_sid_dav_verkehrszaehlung_miv_od2031',
#  'notes': 'Die hier verfügbaren Datensätze beinhalten die **täglich '
#           'aktualisierten** Messwerte zum motorisierten Individualverkehr '
#           '(MIV) in der Stadt Zürich, welche von den zahlreichen Zählstellen '
#           'der Dienstabteilung Verkehr (DAV) gemessen wurden.\n'
#           '\n'
#           'Die Aktualisierung beinhaltet jeweils die Daten von **vorgestern** '
#           '(z.B. am 17.1.2021 werden die Daten bis und mit dem vollendeten '
#           '15.1.2021 geliefert). Bis spätestens 08:00 Uhr sind die neuesten '
#           'Daten verfügbar.\n'
#           '\n'
#           'Zu einer Messstelle gehören mehrere Zählstellen, welche wiederum '
#           'Messungen mit sogenannten Detektoren vornehmen. In den vorliegenden '
#           'Datensätzen sind die Messwerte pro Zählstelle enthalten. Für jede '
#           'Zählstelle gibt es einen detaillierten PDF-Situationsplan in der '
#           'Datei "Zaehlstellen_Detail.zip", welcher u.a. die genaue Lage der '
#           'Detektoren anzeigt.',
#  'num_resources': 2,
#  'num_tags': 13,
#  'organization': {'approval_status': 'approved',
#                   'created': '2015-06-25T13:53:59.198168',
#                   'description': '',
#                   'id': 'stadt-zurich',
#                   'image_url': 'https://www.stadt-zuerich.ch/content/dam/stzh/portal/Deutsch/OGD/Bilder/ckan/platzhalter_org_ckan.png',
#                   'is_organization': True,
#                   'name': 'stadt-zurich',
#                   'revision_id': 'a44568fe-a837-49e1-8cbf-82a713d4c2d7',
#                   'state': 'active',
#                   'title': 'Stadt Zürich',
#                   'type': 'organization'},
#  'owner_org': 'stadt-zurich',
#  'private': False,
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'resources': [{'cache_last_updated': None,
#                 'cache_url': None,
#                 'created': '2022-01-20T16:45:41.914246',
#                 'datastore_active': False,
#                 'datastore_contains_all_records_of_source_file': 'False',
#                 'description': '',
#                 'format': 'CSV',
#                 'hash': '',
#                 'id': '3588f174-f687-4939-82a8-d63088001279',
#                 'last_modified': '2022-11-28T23:36:29.186835',
#                 'mimetype': 'text/csv',
#                 'mimetype_inner': None,
#                 'name': 'sid_dav_verkehrszaehlung_miv_OD2031_2021.csv',
#                 'package_id': '1ed324d3-9659-43ca-a330-6780fef24d99',
#                 'position': 0,
#                 'resource_type': 'file',
#                 'revision_id': 'b18cbc6e-54a2-4148-b1c4-a8fde753ccb5',
#                 'size': 246687800,
#                 'state': 'active',
#                 'url': 'https://data.integ.stadt-zuerich.ch/dataset/int_dwh_sid_dav_verkehrszaehlung_miv_od2031/download/sid_dav_verkehrszaehlung_miv_OD2031_2021.csv',
#                 'url_type': 'upload',
#                 'zh_hash': '63738da73aae073d9865d6a7d4c50eb9'},
#                {'cache_last_updated': None,
#                 'cache_url': None,
#                 'created': '2022-01-20T16:45:48.623300',
#                 'datastore_active': False,
#                 'datastore_contains_all_records_of_source_file': 'False',
#                 'description': '',
#                 'format': 'CSV',
#                 'hash': '',
#                 'id': 'fdce9d36-d5b7-4c98-9b39-e3060ad7d632',
#                 'last_modified': '2022-11-28T23:36:34.352329',
#                 'mimetype': 'text/csv',
#                 'mimetype_inner': None,
#                 'name': 'VER203OD2031.csv',
#                 'package_id': '1ed324d3-9659-43ca-a330-6780fef24d99',
#                 'position': 1,
#                 'resource_type': 'file',
#                 'revision_id': '42b1c760-dc02-4549-815e-4fbdf943780f',
#                 'size': 21446870,
#                 'state': 'active',
#                 'url': 'https://data.integ.stadt-zuerich.ch/dataset/int_dwh_sid_dav_verkehrszaehlung_miv_od2031/download/VER203OD2031.csv',
#                 'url_type': 'upload',
#                 'zh_hash': '3b74571e67c386dbc988afa98beaf1f0'}],
#  'revision_id': '73bc0f81-21b6-4e1e-a301-91afd28f8729',
#  'spatialRelationship': 'Stadt Zürich',
#  'sszBemerkungen': '**Methodik**\n'
#                    '\n'
#                    'Die hier vorhandenen Datensätze weisen die Messwerte der '
#                    'Zählstellen für den motorisierten Individualverkehr (MIV) '
#                    'in der Stadt Zürich seit 2012 aus. Die Werte werden '
#                    '**täglich geliefert** und zeigen jeweils die Stundenwerte '
#                    'pro Zähhlstelle.\n'
#                    '\n'
#                    'Um die Auswertung der Zeitreihe zu erleichtern, wurden '
#                    'fehlende Werte (z.B. durch einen temporären Ausfall einer '
#                    'Zählstelle) durch imputierte Werte ersetzt. Die hier '
#                    'vorgenommene **Imputation** basiert auf den Messwerten zum '
#                    'gleichen Zeitpunkt des gleichen Wochentags aus den letzten '
#                    '5 Jahren. Dazu wird ein Faktor zum jeweiligen Wert der '
#                    'vorher gemessenen Stunde berechnet. \n'
#                    '\n'
#                    '**Formel:**\n'
#                    'f(x) = (Durchschnitt der Stunde a der letzten gültigen 5 '
#                    'Jahre / Durchschnitt Stunde a-1h der letzten gültigen 5 '
#                    'Jahre)\n'
#                    'Impurtierter Wert ax = (Stundenwert a-1h) * f(x)\n'
#                    '\n'
#                    'Imputationen werden nur für einzelne fehlende Stunden '
#                    'vorgenommen. Wenn eine Zählstelle länger ausgefallen sind, '
#                    'werden die entsprechenden Werte jeweils mit '
#                    '`AnzFahrzeugeStatus = Fehlend` gekenntzeichnet.\n'
#                    ' \n'
#                    '\n'
#                    '[]()\n'
#                    '\n'
#                    '**Zeitangaben**\n'
#                    '\n'
#                    'Alle **Zeitangaben** sind lokale Zeiten ([CET - Central '
#                    'Euripean '
#                    'Time](http://www.timeanddate.com/time/zones/cet)). Das '
#                    'Datumsformat entspricht dem [ISO 8601 '
#                    'Standard](http://www.w3.org/TR/NOTE-datetime)\n'
#                    '\n'
#                    'Bei der Zeitumstellung passiert folgendes:\n'
#                    '\n'
#                    '* Vorstellen von 2 auf 3 Uhr: Es fehlt eine Stunde (2 '
#                    'Uhr). An diesem Tag werden nur für **23 Stunden** Werte '
#                    'geliefert.\n'
#                    '* Rückstellen von 3 auf 2 Uhr: Es gibt 2 Werte für 2 Uhr. '
#                    'An diesem Tag werden für **25 Stunden** Werte geliefert. \n'
#                    '\n'
#                    ' \n'
#                    '\n'
#                    '[]()\n'
#                    '\n',
#  'sszFields': '[["Identifikationsnummer der Messstelle (technisch: MSID)", '
#               '"Identifikationsnummer der Messstelle (String)"], ["Name der '
#               'Messstelle (technisch: MSName)", "Name der Messstelle '
#               '(String)"], ["Identifikationsnummer Z\\u00e4hlstelle '
#               '(technisch: ZSID)", "Identifikationsnummer der Z\\u00e4hlstelle '
#               '(String)"], ["Name der Z\\u00e4hlstelle (technisch: ZSName)", '
#               '"Name der Z\\u00e4hlstelle (String)"], ["Achse (Strasse) der '
#               'Messstelle (technisch: Achse)", "Strasse an der die '
#               'Z\\u00e4hlstelle steht (String)"], ["Hausnummer (technisch: '
#               'HNr)", "Wenn m\\u00f6glich wird die Adresse (Strassenname und '
#               'Hausnummer), bei der die Z\\u00e4hlstelle steht, angegeben. '
#               'Ansonsten steht der Wert \\"Unbekannt\\" in diesem Feld '
#               '(String)"], ["H\\u00f6he der Achse (Bezeichnung) (technisch: '
#               'Hoehe)", "Bezeichnung auf welcher H\\u00f6he bei der Achse sich '
#               'die Z\\u00e4hlstelle befindet"], ["Ost-Koordinate (technisch: '
#               'EKoord)", "Ost-Koordinate (CH1903+/LV95)"], ["Nord-Koordinate '
#               '(technisch: NKoord)", "Nord-Koordinate (CH1903+/LV95)"], '
#               '["Richtung der Messung (technisch: Richtung)", "Richtung in die '
#               'eine Z\\u00e4hlstelle misst (String)"], ["Identifikationsnummer '
#               'Gruppe (technisch: Knummer)", "Identifikationsnummer der Gruppe '
#               'von Messstellen. Messstellen sind meistens in Gruppen '
#               'zusammengefasst, welche r\\u00e4umlich nahe beieinander liegen '
#               '(z.B. stadteinw\\u00e4rts und stadtausw\\u00e4rts an der '
#               'gleichen Strasse)"], ["Name der Gruppe (technisch: Kname)", '
#               '"Name der Gruppe von Messstellen (String)"], ["Anzahl '
#               'Detektoren (technisch: AnzDetektoren)", "Anzahl Detektoren der '
#               'Z\\u00e4hlstelle (Integer)"], ["Detektor 1 der Messstelle '
#               '(technisch: D1ID)", "ID des Detektors 1 der Z\\u00e4hlstelle '
#               'oder \\"Unbekannt\\" (String)"], ["Detektor 2 der Messstelle '
#               '(technisch: D2ID)", "ID des Detektors 2 der Z\\u00e4hlstelle '
#               'oder \\"Unbekannt\\" (String)"], ["Detektor 3 der Messstelle '
#               '(technisch: D3ID)", "ID des Detektors 3 der Z\\u00e4hlstelle '
#               'oder \\"Unbekannt\\" (String)"], ["Detektor 4 der Messtelle '
#               '(technisch: D4ID)", "ID des Detektors 4 der Z\\u00e4hlstelle '
#               'oder \\"Unbekannt\\" (String)"], ["Datum und Zeit der Messung '
#               '(technisch: MessungDatZeit)", "Eine Messung bezieht sich immer '
#               'auf eine Stunde. Dieses Feld gibt den Startzeitpunkt der '
#               'Messung an (Datetime, ISO-8601)"], ["Datum der Lieferung '
#               '(technisch: LieferDat)", "Die Daten werden t\\u00e4glich '
#               'geliefert. Dieses Feld gibt an, wann die Daten zuletzt '
#               'geliefert wurden (Date, ISO-8601)"], ["Anzahl Fahrzeuge '
#               '(technisch: AnzFahrzeuge)", "Die Anzahl Fahrzeuge in der Stunde '
#               '(gem\\u00e4ss MessungDatZeit) an dieser Z\\u00e4hlstelle. Wenn '
#               'der Wert fehlt, gibt es f\\u00fcr diesen Zeitpunkt keine '
#               'Messung (Integer)"], ["Status des Messung (technisch: '
#               'AnzFahrzeugeStatus)", "Dieses Feld gibt an, wie der Wert in '
#               'AnzFahrzeuge zustande kam. M\\u00f6gliche Werte: Gemessen '
#               '(=gemessener Wert von der Messstelle), Fehlend (=es wurde kein '
#               'Wert gemessen, z.B. beim Ausfall der Messstelle), Imputiert '
#               '(=es wurde kein Wert gemessen, stattdessen wurde der Wert '
#               'imputiert, d.h. anhand historischer Daten '
#               'vervollst\\u00e4ndigt.  SIehe dazu auch die Bemerkungen zur '
#               'Methodik) (String)"]]',
#  'state': 'active',
#  'tags': [{'display_name': 'auto',
#            'id': '46e9bb51-f281-4148-b79f-dee372ac1570',
#            'name': 'auto',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'lastwagen',
#            'id': '0d83e705-89d1-4f08-935f-53ba6044f3b9',
#            'name': 'lastwagen',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'messwert',
#            'id': '45340d3e-bb16-4a34-9962-7d7b8ca124b4',
#            'name': 'messwert',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'motorrad',
#            'id': '8b966597-03a7-4eb2-a04d-dff020e52803',
#            'name': 'motorrad',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'sachdaten',
#            'id': '693d1584-be71-4808-bef8-9fa2f7c12883',
#            'name': 'sachdaten',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'sasa',
#            'id': '443557a8-212a-42fa-8f2a-fa064ac7ad9c',
#            'name': 'sasa',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'stau',
#            'id': '33068eab-c7cf-41e1-af18-fa217e336628',
#            'name': 'stau',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'tabelle',
#            'id': 'dd8ce140-4d66-4bac-b3ba-9674c839ee7e',
#            'name': 'tabelle',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'verkehr',
#            'id': 'd179ad41-4b4f-413e-895e-540b54f73810',
#            'name': 'verkehr',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'verkehrszaehlung',
#            'id': '6f416e67-8118-49f7-9f46-bdc0d57fb9cf',
#            'name': 'verkehrszaehlung',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'zeitreihe',
#            'id': '5d73d4cc-2593-4b5d-9809-1a8bfe630958',
#            'name': 'zeitreihe',
#            'state': 'active',
#            'vocabulary_id': None}],
#  'timeRange': '2012 - vorgestern',
#  'title': 'Daten der Verkehrszählung zum motorisierten Individualverkehr '
#           '(Stundenwerte), seit 2012',
#  'type': 'dataset',
#  'updateInterval': ['taeglich'],
#  'url': 'Statistik Stadt Zürich, Präsidialdepartement',
#  'version': '1'}
# c:\Users\sszods\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.szh.loc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'author': 'Bevölkerungsamt, Präsidialdepartement',
#  'author_email': None,
#  'creator_user_id': 'd2e1adfa-4bdb-4022-a3b9-6d56ffbb9f31',
#  'dataQuality': 'gut',
#  'dataType': ['Datenaggregat'],
#  'dateFirstPublished': '08.07.2016',
#  'dateLastUpdated': '29.11.2022',
#  'extras': [{'key': 'harvest_object_id',
#              'value': '4e9f41f7-345d-47c2-ac57-12f486241823'},
#             {'key': 'harvest_source_id',
#              'value': 'cc11cf5d-747f-4a65-a0a2-7786b99e3c76'},
#             {'key': 'harvest_source_title',
#              'value': 'INT_DWH Dropzone Harvester'}],
#  'groups': [{'description': '',
#              'display_name': 'Be\xadvölk\xaderung',
#              'id': 'bevolkerung',
#              'image_display_url': 'https://statistik.stadt-zuerich.ch/modules/ogd_bspe/group_pics/kategorien-04.png',
#              'name': 'bevolkerung',
#              'title': 'Be\xadvölk\xaderung'}],
#  'id': '0b38d84b-c064-4c90-9d03-dc516bcf51c3',
#  'isopen': True,
#  'legalInformation': '',
#  'license_id': 'cc-zero',
#  'license_title': 'Creative Commons CCZero',
#  'license_url': 'http://www.opendefinition.org/licenses/cc-zero',
#  'maintainer': 'Open Data Zürich',
#  'maintainer_email': 'opendata@zuerich.ch',
#  'metadata_created': '2022-01-20T08:51:02.982566',
#  'metadata_modified': '2022-11-28T23:37:51.719498',
#  'name': 'int_dwh_bev_monat_bestand_quartier_geschl_ag_herkunft_od3250',
#  'notes': '\n'
#           'Anzahl wirtschaftliche Bevölkerung nach Monat, Altersgruppe, '
#           'Geschlecht, Herkunft, Stadtkreis und Stadtquartier, seit 1998.\n'
#           '\n'
#           'Im aktuellen Jahr handelt es sich um **provisorische** Daten. Diese '
#           'können laufend korrigiert werden. Erst mit dem Jahresabschluss '
#           'werden die Daten definitiv.\n'
#           ' \n',
#  'num_resources': 1,
#  'num_tags': 8,
#  'organization': {'approval_status': 'approved',
#                   'created': '2015-06-25T13:53:59.198168',
#                   'description': '',
#                   'id': 'stadt-zurich',
#                   'image_url': 'https://www.stadt-zuerich.ch/content/dam/stzh/portal/Deutsch/OGD/Bilder/ckan/platzhalter_org_ckan.png',
#                   'is_organization': True,
#                   'name': 'stadt-zurich',
#                   'revision_id': 'a44568fe-a837-49e1-8cbf-82a713d4c2d7',
#                   'state': 'active',
#                   'title': 'Stadt Zürich',
#                   'type': 'organization'},
#  'owner_org': 'stadt-zurich',
#  'private': False,
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'resources': [{'cache_last_updated': None,
#                 'cache_url': None,
#                 'created': '2022-01-20T16:46:40.326162',
#                 'datastore_active': False,
#                 'datastore_contains_all_records_of_source_file': 'False',
#                 'description': '',
#                 'format': 'CSV',
#                 'hash': '',
#                 'id': '9726d9ab-4972-49c8-bd09-aedcb444461b',
#                 'last_modified': '2022-11-28T23:37:50.602169',
#                 'mimetype': 'text/csv',
#                 'mimetype_inner': None,
#                 'name': 'BEV325OD3250.csv',
#                 'package_id': '0b38d84b-c064-4c90-9d03-dc516bcf51c3',
#                 'position': 0,
#                 'resource_type': 'file',
#                 'revision_id': 'd0037dbf-f417-4743-b3c9-0fc6e58a27aa',
#                 'size': 24805437,
#                 'state': 'active',
#                 'url': 'https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bev_monat_bestand_quartier_geschl_ag_herkunft_od3250/download/BEV325OD3250.csv',
#                 'url_type': 'upload',
#                 'zh_hash': '91715f8462405685155abd0919afeaf7'}],
#  'revision_id': 'e6492259-a6a6-450f-a329-b2d7ed560e81',
#  'spatialRelationship': 'Stadt Zürich',
#  'sszBemerkungen': '**Datenstand**\n'
#                    '\n'
#                    '- **Aktuellster Monat**: Der aktuellste Monat in den Daten '
#                    'enspricht dem aktuellen Monat - 2 Monate.\n'
#                    '\n'
#                    '- **Datenqualität**: Im laufend aktuellen Jahr sind die '
#                    'Daten provisorisch und werden laufend korrigiert.\n'
#                    '\n'
#                    '- **Variable Datenstand**: Die Variablen DatenstandCd und '
#                    'DatenstandLang beschreiben den Datenstand. Provisorische '
#                    'Daten werden laufend korrigiert.\n'
#                    '\n'
#                    '- **Hintergrund-Information**: Die Daten der letzten zwei '
#                    'Kalenderjahre (Januar bis Dezember) basieren auf den '
#                    'gespeicherten Datenbeständen des Bevölkerungsregisters. '
#                    'Die vorangehenden Monatsdaten wurden aufgrund der '
#                    'Bewegungen (Geburten, Todesfälle, Zuzüge von auswärts, '
#                    'Wegzüge nach auswärts, Umzüge innerhalb der Stadt, '
#                    'Einbürgerungen) berechnet.\n'
#                    '\n'
#                    ' \n'
#                    '\n'
#                    '[]()\n'
#                    '\n',
#  'sszFields': '[["Jahr (technisch: StichtagDatJahr)", "Jahr des Stichtages '
#               '(Integer)."], ["Monat (technisch: StichtagDatMM)", "Monat des '
#               'Stichtages (Integer)."], ["Monat (technisch: '
#               'StichtagDatMonat)", "Monat des Stichtages (String)."], ["Tag '
#               '(technisch: StichtagDat)", "Tag des Stichtages (Integer); Tage '
#               'seit dem 1.1.1960."], ["Geschlecht (technisch: SexCd)", '
#               '"Geschlecht Code (Integer)."], ["Geschlecht (technisch: '
#               'SexLang)", "Geschlecht (String)."], ["Altersgruppe (technisch: '
#               'AlterV20Sort)", "Altersgruppe Sort (String)."], ["Altersgruppe '
#               '(technisch: AlterV20Kurz)", "Altersgruppe (String)."], '
#               '["Herkunft (technisch: HerkunftCd)", "Herkunft Code '
#               '(Integer)."], ["Herkunft (technisch: HerkunftLang)", "Herkunft '
#               'Bezeichnung (String)."], ["Stadtkreis (technisch: KreisCd)", '
#               '"Stadtkreis Code (Integer)."], ["Stadtkreis (technisch: '
#               'KreisLang)", "Stadtkreis (String)."], ["Stadtquartier '
#               '(technisch: QuarCd)", "Stadtquartier Code (Integer)."], '
#               '["Stadtquartier (technisch: QuarLang)", "Stadtquartier '
#               '(String)."], ["Datenstand (technisch: DatenstandCd)", '
#               '"Datenstand Code (Integer)."], ["Datenstand (technisch: '
#               'DatenstandLang)", "Datenstand (String)."], ["wirtschaftliche '
#               'Bev\\u00f6lkerung (technisch: AnzBestWir)", "Anzahl Personen '
#               'aus der wirtschaftlichen Wohnbev\\u00f6lkerung (Integer)."]]',
#  'state': 'active',
#  'tags': [{'display_name': 'migration',
#            'id': 'bfecdb58-ee95-49d2-97da-5522084ac70c',
#            'name': 'migration',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'monatsdaten',
#            'id': 'faef5471-01c2-4c54-bcc4-9b71b0a14ca1',
#            'name': 'monatsdaten',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'sachdaten',
#            'id': '693d1584-be71-4808-bef8-9fa2f7c12883',
#            'name': 'sachdaten',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'sasa',
#            'id': '443557a8-212a-42fa-8f2a-fa064ac7ad9c',
#            'name': 'sasa',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'tabelle',
#            'id': 'dd8ce140-4d66-4bac-b3ba-9674c839ee7e',
#            'name': 'tabelle',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'zeitreihe',
#            'id': '5d73d4cc-2593-4b5d-9809-1a8bfe630958',
#            'name': 'zeitreihe',
#            'state': 'active',
#            'vocabulary_id': None}],
#  'timeRange': '1.1998 –  9.2022',
#  'title': 'Bevölkerung nach Monat, Stadtquartier, Geschlecht, Altersgruppe und '
#           'Herkunft, seit 1998',
#  'type': 'dataset',
#  'updateInterval': ['monatlich'],
#  'url': 'Statistik Stadt Zürich, Präsidialdepartement',
#  'version': '1.0'}
# c:\Users\sszods\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.szh.loc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'author': 'Beschäftigtenstatistik, Bundesamt für Statistik',
#  'author_email': None,
#  'creator_user_id': 'd2e1adfa-4bdb-4022-a3b9-6d56ffbb9f31',
#  'dataQuality': 'siehe Bemerkungen',
#  'dataType': ['Datenaggregat'],
#  'dateFirstPublished': '20.06.2021',
#  'dateLastUpdated': '29.11.2022',
#  'extras': [{'key': 'harvest_object_id',
#              'value': '5d597283-d5a7-4a7f-81c0-8a003f9f0d97'},
#             {'key': 'harvest_source_id',
#              'value': 'cc11cf5d-747f-4a65-a0a2-7786b99e3c76'},
#             {'key': 'harvest_source_title',
#              'value': 'INT_DWH Dropzone Harvester'}],
#  'groups': [{'description': '',
#              'display_name': 'Arbeit und Erwerb',
#              'id': '1f96ec7f-838a-4592-8f79-b6bf6806ad01',
#              'image_display_url': 'https://statistik.stadt-zuerich.ch/modules/ogd_bspe/group_pics/kategorien-01.png',
#              'name': 'arbeit-und-erwerb',
#              'title': 'Arbeit und Erwerb'}],
#  'id': 'd5ea6ab1-f33c-46f3-bbb9-c6711b9ad02a',
#  'isopen': True,
#  'legalInformation': '',
#  'license_id': 'cc-zero',
#  'license_title': 'Creative Commons CCZero',
#  'license_url': 'http://www.opendefinition.org/licenses/cc-zero',
#  'maintainer': 'Open Data Zürich',
#  'maintainer_email': 'opendata@zuerich.ch',
#  'metadata_created': '2022-09-01T10:23:31.364172',
#  'metadata_modified': '2022-11-28T23:35:49.067631',
#  'name': 'int_dwh_bfs_wir_besch_sektor_geschlecht_beschgrad_vzaeq_jahr_od4002',
#  'notes': '\n'
#           'Diese Daten beinhalten aggreggierte Beschäftigtenzahlen in der '
#           'Stadt Zürich und den nächsthöheren Ebenen. Die Daten für die Stadt '
#           'Zürich werden nach diversen Merkmalen unterteilt (Sektor, '
#           'Geschlecht, Beschäftigungsgrad). Ausserdem werden für die Stadt '
#           'Zürich auch noch Vollzeitäquivalente ausgewiesen.\n'
#           '\n'
#           'Bitte beachten Sie für das korrekte Verständnis zu den Daten die '
#           'unten aufgeführten weiteren Erläuterungen in der Rubrik '
#           '**«Bemerkungen»**.\n'
#           '\n',
#  'num_resources': 1,
#  'num_tags': 9,
#  'organization': {'approval_status': 'approved',
#                   'created': '2015-06-25T13:53:59.198168',
#                   'description': '',
#                   'id': 'stadt-zurich',
#                   'image_url': 'https://www.stadt-zuerich.ch/content/dam/stzh/portal/Deutsch/OGD/Bilder/ckan/platzhalter_org_ckan.png',
#                   'is_organization': True,
#                   'name': 'stadt-zurich',
#                   'revision_id': 'a44568fe-a837-49e1-8cbf-82a713d4c2d7',
#                   'state': 'active',
#                   'title': 'Stadt Zürich',
#                   'type': 'organization'},
#  'owner_org': 'stadt-zurich',
#  'private': False,
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'resources': [{'cache_last_updated': None,
#                 'cache_url': None,
#                 'ckan_url': 'https://ckan-ogdzh-integ.clients.liip.ch',
#                 'created': '2022-09-01T10:23:33.238688',
#                 'datastore_active': True,
#                 'datastore_contains_all_records_of_source_file': 'True',
#                 'description': '',
#                 'format': 'CSV',
#                 'hash': '457872b29c3ffd43385387ebab94567a',
#                 'id': 'df95bcf8-1b54-4cb7-a0cf-4ca40089f01a',
#                 'ignore_hash': 'False',
#                 'last_modified': '2022-11-28T23:35:45.759026',
#                 'mimetype': 'text/csv',
#                 'mimetype_inner': None,
#                 'name': 'WIR400OD4002.csv',
#                 'original_url': 'https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bfs_wir_besch_sektor_geschlecht_beschgrad_vzaeq_jahr_od4002/download/WIR400OD4002.csv',
#                 'package_id': 'd5ea6ab1-f33c-46f3-bbb9-c6711b9ad02a',
#                 'position': 0,
#                 'resource_id': 'df95bcf8-1b54-4cb7-a0cf-4ca40089f01a',
#                 'resource_type': 'file',
#                 'revision_id': '685cb882-71a6-4800-ada7-f4ce74002a93',
#                 'set_url_type': 'False',
#                 'size': 14686,
#                 'state': 'active',
#                 'task_created': '2022-11-28 23:35:46.035141',
#                 'url': 'https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bfs_wir_besch_sektor_geschlecht_beschgrad_vzaeq_jahr_od4002/download/WIR400OD4002.csv',
#                 'url_type': 'upload',
#                 'zh_hash': '457872b29c3ffd43385387ebab94567a'}],
#  'revision_id': '87e67937-f9bb-483b-b651-72f28229ec6d',
#  'spatialRelationship': 'Stadt Zürich, zu Vergleichszwecken auch Kanton Zürich '
#                         'und Schweiz',
#  'sszBemerkungen': '**BESTA:**\n'
#                    '\n'
#                    ' Die dargestellten Werte stammen aus der '
#                    'Beschäftigtenstatistik (BESTA) des Bundesamtes für '
#                    'Statistik.\n'
#                    '\n'
#                    'Die seit 1925 als Quartalsstatistik durchgeführte BESTA, '
#                    'beruht heute auf einer repräsentativen Stichprobe von '
#                    "18‘000 Unternehmen (65'000 Betrieben) des sekundären und "
#                    'tertiären Sektors. Ziel der Statistik ist die Erstellung '
#                    'von verschiedenen Konjunkturindikatoren, die die '
#                    'Entwicklung der Beschäftigung in der Schweiz verfolgen.\n'
#                    '\n'
#                    'Für weitere Informationen dazu, siehe [Steckbrief '
#                    'BESTA](https://www.bfs.admin.ch/bfs/de/home/statistiken/industrie-dienstleistungen/erhebungen/besta.assetdetail.6917.html)\n'
#                    '\n'
#                    ' \n'
#                    '\n'
#                    '[]()\n'
#                    '\n'
#                    '**Definitionen:**\n'
#                    '\n'
#                    ' \n'
#                    '\n'
#                    '- **Vollzeitbeschäftigte**: Beschäftigte ab 90 Prozent der '
#                    'betriebsüblichen wöchentlichen Arbeitszeit.\n'
#                    '\n'
#                    '- **Teilzeitbeschäftigte**: Beschäftigte bis 89 Prozent '
#                    'der betriebsüblichen wöchentlichen Arbeitszeit.\n'
#                    '\n'
#                    '- **Vollzeitäquivalente**: Die Beschäftigung in '
#                    'Vollzeitäquivalenten resultiert aus der Umrechnung des '
#                    'Arbeitsvolumens (gemessen als Beschäftigte oder '
#                    'Arbeitsstunden) in Vollzeitbeschäftigte. Die Beschäftigung '
#                    'in Vollzeitäquivalenten ist definiert als das Total der '
#                    'geleisteten Arbeitsstunden dividiert durch das '
#                    'Jahresmittel der Arbeitsstunden, die durch '
#                    'Vollzeitbeschäftigte erbracht werden.\n'
#                    ' \n'
#                    '\n'
#                    '[]()\n'
#                    '\n',
#  'sszFields': '[["Jahr (technisch: Jahr)", "Jahr"], ["Quartal (technisch: '
#               'Quartal)", "Quartal"], ["Besch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich (technisch: stzh_tot)", "Anzahl Besch\\u00e4ftigte '
#               'in der Stadt Z\\u00fcrich Total"], ["Weibliche '
#               'Besch\\u00e4ftigte in der Stadt Z\\u00fcrich (technisch: '
#               'stzh_frau)", "Anzahl Besch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich weiblich"], ["M\\u00e4nnliche Besch\\u00e4ftigte '
#               'in der Stadt Z\\u00fcrich (technisch: stzh_mann)", "Anzahl '
#               'Besch\\u00e4ftigte in der Stadt Z\\u00fcrich m\\u00e4nnlich"], '
#               '["Besch\\u00e4ftigte in der Stadt Z\\u00fcrich im 2. Sektor '
#               '(technisch: stzh_s2)", "Anzahl Besch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich im 2. Sektor"], ["Besch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich im 3. Sektor (technisch: stzh_s3)", "Anzahl '
#               'Besch\\u00e4ftigte in der Stadt Z\\u00fcrich im 3. Sektor"], '
#               '["Teilzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich '
#               '(technisch: stzh_TZB_tot)", "Anzahl Teilzeitbesch\\u00e4ftigte '
#               'in der Stadt Z\\u00fcrich Total"], ["Weibliche '
#               'Teilzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich '
#               '(technisch: stzh_TZB_Frauen)", "Anzahl '
#               'Teilzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich '
#               'weiblich"], ["M\\u00e4nnliche Teilzeitbesch\\u00e4ftigte in der '
#               'Stadt Z\\u00fcrich (technisch: stzh_TZB_Maenner)", "Anzahl '
#               'Teilzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich '
#               'm\\u00e4nnlich"], ["Teilzeitbesch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich im 2. Sektor (technisch: stzh_TZB_s2)", "Anzahl '
#               'Teilzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich im 2. '
#               'Sektor"], ["Teilzeitbesch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich im 3. Sektor (technisch: stzh_TZB_s3)", "Anzahl '
#               'Teilzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich im 3. '
#               'Sektor"], ["Vollzeit\\u00e4quivalente in der Stadt Z\\u00fcrich '
#               '(technisch: stzh_VZA_tot)", "Anzahl Vollzeit\\u00e4quivalente '
#               'in der Stadt Z\\u00fcrich Total"], ["Weibliche '
#               'Vollzeit\\u00e4quivalente in der Stadt Z\\u00fcrich (technisch: '
#               'stzh_VZA_Frauen)", "Anzahl Vollzeit\\u00e4quivalente in der '
#               'Stadt Z\\u00fcrich weiblich"], ["M\\u00e4nnliche '
#               'Vollzeit\\u00e4quivalente in der Stadt Z\\u00fcrich (technisch: '
#               'stzh_VZA_Maenner)", "Anzahl Vollzeit\\u00e4quivalente in der '
#               'Stadt Z\\u00fcrich m\\u00e4nnlich"], '
#               '["Vollzeit\\u00e4quivalente in der Stadt Z\\u00fcrich im 2. '
#               'Sektor (technisch: stzh_VZA_s2)", "Anzahl '
#               'Vollzeit\\u00e4quivalente in der Stadt Z\\u00fcrich im 2. '
#               'Sektor"], ["Vollzeit\\u00e4quivalente in der Stadt Z\\u00fcrich '
#               'im 3. Sektor (technisch: stzh_VZA_s3)", "Anzahl '
#               'Vollzeit\\u00e4quivalente in der Stadt Z\\u00fcrich im 3. '
#               'Sektor"], ["Vollzeitbesch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich Total (technisch: stzh_VZB_tot)", "Anzahl '
#               'Vollzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich Total"], '
#               '["Weibliche Vollzeitbesch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich (technisch: stzh_VZB_Frauen)", "Anzahl '
#               'Vollzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich '
#               'weiblich"], ["M\\u00e4nnliche Vollzeitbesch\\u00e4ftigte in der '
#               'Stadt Z\\u00fcrich (technisch: stzh_VZB_Maenner)", "Anzahl '
#               'Vollzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich '
#               'm\\u00e4nnlich"], ["Vollzeitbesch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich im 2. Sektor (technisch: stzh_VZB_s2)", "Anzahl '
#               'Vollzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich im 2. '
#               'Sektor"], ["Vollzeitbesch\\u00e4ftigte in der Stadt '
#               'Z\\u00fcrich im 3. Sektor (technisch: stzh_VZB_s3)", "Anzahl '
#               'Vollzeitbesch\\u00e4ftigte in der Stadt Z\\u00fcrich im 3. '
#               'Sektor"], ["Besch\\u00e4ftigte im Kanton Z\\u00fcrich '
#               '(technisch: zh_tot)", "Anzahl Besch\\u00e4ftigte im Kanton '
#               'Z\\u00fcrich Total"], ["Besch\\u00e4ftigte im Kanton '
#               'Z\\u00fcrich im 2. Sektor (technisch: zh_s2)", "Anzahl '
#               'Besch\\u00e4ftigte im Kanton Z\\u00fcrich im 2. Sektor"], '
#               '["Besch\\u00e4ftigte im Kanton Z\\u00fcrich im 3. Sektor '
#               '(technisch: zh_s3)", "Anzahl Besch\\u00e4ftigte im Kanton '
#               'Z\\u00fcrich im 3. Sektor"], ["Besch\\u00e4ftigte in der '
#               'Schweiz (technisch: ch_tot)", "Anzahl Besch\\u00e4ftigte in der '
#               'Schweiz Total"], ["Besch\\u00e4ftigte in der Schweiz im 2. '
#               'Sektor (technisch: ch_s2)", "Anzahl Besch\\u00e4ftigte in der '
#               'Schweiz im 2. Sektor"], ["Besch\\u00e4ftigte in der Schweiz im '
#               '3. Sektor (technisch: ch_s3)", "Anzahl Besch\\u00e4ftigte in '
#               'der Schweiz im 3. Sektor"]]',
#  'state': 'active',
#  'tags': [{'display_name': 'beschaeftigte',
#            'id': '1ed7c532-23a3-494b-bb4b-f32824870520',
#            'name': 'beschaeftigte',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'sachdaten',
#            'id': '693d1584-be71-4808-bef8-9fa2f7c12883',
#            'name': 'sachdaten',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'sasa',
#            'id': '443557a8-212a-42fa-8f2a-fa064ac7ad9c',
#            'name': 'sasa',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'tabelle',
#            'id': 'dd8ce140-4d66-4bac-b3ba-9674c839ee7e',
#            'name': 'tabelle',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'vollzeitaequivalente',
#            'id': '8884163e-7552-4cbd-8355-4b177b1ff513',
#            'name': 'vollzeitaequivalente',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'wirtschaftssektor',
#            'id': 'da623ae1-2baa-43f0-963a-571d392f522b',
#            'name': 'wirtschaftssektor',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'zeitreihe',
#            'id': '5d73d4cc-2593-4b5d-9809-1a8bfe630958',
#            'name': 'zeitreihe',
#            'state': 'active',
#            'vocabulary_id': None}],
#  'timeRange': '2003-2022',
#  'title': 'Beschäftigte nach Sektor, Geschlecht und Beschäftigungsgrad, '
#           'Vollzeitäquivalente, seit Q2 2003',
#  'type': 'dataset',
#  'updateInterval': ['quartalsweise'],
#  'url': 'Statistik Stadt Zürich, Präsidialdepartement',
#  'version': '1.0'}
# c:\Users\sszods\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.szh.loc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'author': 'Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- '
#            'und Umweltdepartement',
#  'author_email': None,
#  'creator_user_id': 'd2e1adfa-4bdb-4022-a3b9-6d56ffbb9f31',
#  'dataQuality': '\n'
#                 'Bei den Daten mit dem Status «provisorisch» handelt es sich '
#                 'um vorläufige Messwerte, welche Ausreisser oder '
#                 'Gerätefehlfunktionen enthalten können. Daten mit dem Status '
#                 '«bereinigt» enthalten bereinigte Messwerte und werden nicht '
#                 'mehr geändert.\n',
#  'dataType': ['Datenaggregat'],
#  'dateFirstPublished': '',
#  'dateLastUpdated': '29.11.2022',
#  'extras': [{'key': 'harvest_object_id',
#              'value': '83264f2c-085a-4a77-b066-c95b9260aa3d'},
#             {'key': 'harvest_source_id',
#              'value': '9505fe76-e36e-41e2-a68b-274b997cdce9'},
#             {'key': 'harvest_source_title',
#              'value': 'INT_GUD Dropzone Harvester'}],
#  'groups': [{'description': '',
#              'display_name': 'Gesundheit',
#              'id': 'gesundheit',
#              'image_display_url': 'https://statistik.stadt-zuerich.ch/Modules/ogd_bspe/group_pics/kategorien-09.png',
#              'name': 'gesundheit',
#              'title': 'Gesundheit'},
#             {'description': '',
#              'display_name': 'Umwelt',
#              'id': 'umwelt',
#              'image_display_url': 'https://statistik.stadt-zuerich.ch/Modules/ogd_bspe/group_pics/kategorien-17.png',
#              'name': 'umwelt',
#              'title': 'Umwelt'}],
#  'id': '1d82c747-bdc2-4d7a-95c7-58dc0761fff3',
#  'isopen': True,
#  'legalInformation': 'Luftreinhalte-Verordnung (LRV) SR 814.318.142.1, '
#                      'Bundesgesetz über den Umweltschutz (USG) SR 814.01',
#  'license_id': 'cc-zero',
#  'license_title': 'Creative Commons CCZero',
#  'license_url': 'http://www.opendefinition.org/licenses/cc-zero',
#  'maintainer': 'Open Data Zürich',
#  'maintainer_email': 'opendata@zuerich.ch',
#  'metadata_created': '2022-10-25T08:26:50.476214',
#  'metadata_modified': '2022-11-29T11:05:57.933155',
#  'name': 'int_gud_ugz_luftschadstoffmessung_stundenwerte',
#  'notes': '\n'
#           'Dieses Dataset umfasst **Stundenmesswerte seit 1983 bis zur letzten '
#           'aktuellen Stunde**, aufgeteilt in Jahresdateien. Darin enthalten '
#           'sind die **Stundenmittelwerte** des entsprechenden Jahres für die '
#           'Stationen Stampfenbachstrasse, Schimmelstrasse, Rosengartenstrasse '
#           'und Heubeeribüel. Gemessen wird Ozon (O3), Stickoxide (NOx), '
#           'Stickstoffmonoxid (NO), Stickstoffdioxid (NO2), Feinstaub (PM10 und '
#           'PM2.5), Kohlenmonoxid (CO) und Schwefeldioxid (SO2) wo jeweils in '
#           'genügender Qualität vorhanden.\n'
#           '\n'
#           'Die Stundenmittelwerte des laufenden Jahres werden jeweils 30 '
#           'Minuten nach der vollen Stunde aktualisiert.\n',
#  'num_resources': 42,
#  'num_tags': 26,
#  'organization': {'approval_status': 'approved',
#                   'created': '2015-06-25T13:53:59.198168',
#                   'description': '',
#                   'id': 'stadt-zurich',
#                   'image_url': 'https://www.stadt-zuerich.ch/content/dam/stzh/portal/Deutsch/OGD/Bilder/ckan/platzhalter_org_ckan.png',
#                   'is_organization': True,
#                   'name': 'stadt-zurich',
#                   'revision_id': 'a44568fe-a837-49e1-8cbf-82a713d4c2d7',
#                   'state': 'active',
#                   'title': 'Stadt Zürich',
#                   'type': 'organization'},
#  'owner_org': 'stadt-zurich',
#  'private': False,
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'resources': [{'cache_last_updated': None,
#                 'cache_url': None,
#                 'ckan_url': 'https://ckan-ogdzh-integ.clients.liip.ch',
#                 'created': '2022-10-25T08:26:52.277226',
#                 'datastore_active': True,
#                 'datastore_contains_all_records_of_source_file': 'True',
#                 'description': '',
#                 'format': 'XLSX',
#                 'hash': '96c4570c8fbac6ab1dcf37fa6d4195c7',
#                 'id': '472ce4c2-1db5-4303-9027-f9006984d749',
#                 'ignore_hash': 'False',
#                 'last_modified': '2022-11-29T11:04:54.387672',
#                 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet',
#                 'mimetype_inner': None,
#                 'name': 'ugz_luftschadstoffmessung_stundenwerte_Meta.xlsx',
#                 'original_url': 'https://data.integ.stadt-zuerich.ch/dataset/int_gud_ugz_luftschadstoffmessung_stundenwerte/download/ugz_luftschadstoffmessung_stundenwerte_Meta.xlsx',
#                 'package_id': '1d82c747-bdc2-4d7a-95c7-58dc0761fff3',
#                 'position': 0,
#                 'resource_id': '472ce4c2-1db5-4303-9027-f9006984d749',
#                 'resource_type': 'file',
#                 'revision_id': '20989134-2352-409d-b324-30021001e72d',
#                 'set_url_type': 'False',
#                 'size': 42728,
#                 'state': 'active',
#                 'task_created': '2022-10-25 08:26:52.620497',
#                 'url': 'https://data.integ.stadt-zuerich.ch/dataset/int_gud_ugz_luftschadstoffmessung_stundenwerte/download/ugz_luftschadstoffmessung_stundenwerte_Meta.xlsx',
#                 'url_type': 'upload',
#                 'zh_hash': '96c4570c8fbac6ab1dcf37fa6d4195c7'},
#                {'cache_last_updated': None,
#                 'cache_url': None,
#                 'ckan_url': 'https://ckan-ogdzh-integ.clients.liip.ch',
#                 'created': '2022-10-25T08:26:52.872129',
#                 'datastore_active': True,
#                 'datastore_contains_all_records_of_source_file': 'True',
#                 'description': '',
#                 'format': 'CSV',
#                 'hash': 'db07ea7c55517ffd98ae4b1aa0735f6d',
#                 'id': '8a025359-8940-411b-9408-2300d5cce154',
#                 'ignore_hash': 'False',
#                 'last_modified': '2022-11-29T11:04:55.703089',
#                 'mimetype': 'text/csv',
#                 'mimetype_inner': None,
#                 'name': 'ugz_ogd_air_h1_1983.csv',
#                 'original_url': 'https://data.integ.stadt-zuerich.ch/dataset/int_gud_ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1983.csv',
#                 'package_id': '1d82c747-bdc2-4d7a-95c7-58dc0761fff3',
#                 'position': 1,
#                 'resource_id': '8a025359-8940-411b-9408-2300d5cce154',
#                 'resource_type': 'file',
#                 'revision_id': '20989134-2352-409d-b324-30021001e72d',
#                 'set_url_type': 'False',
#                 'size': 3786321,
#                 'state': 'active',
#                 'task_created': '2022-10-25 08:26:53.407892',
#                 'url': 'https://data.integ.stadt-zuerich.ch/dataset/int_gud_ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1983.csv',
#                 'url_type': 'upload',
#                 'zh_hash': 'db07ea7c55517ffd98ae4b1aa0735f6d'},
#                {'cache_last_updated': None,
#                 'cache_url': None,
#                 'ckan_url': 'https://ckan-ogdzh-integ.clients.liip.ch',
#                 'created': '2022-10-25T08:26:53.584092',
#                 'datastore_active': True,
#                 'datastore_contains_all_records_of_source_file': 'True',
#                 'description': '',
#                 'format': 'CSV',
#                 'hash': '8ef3cb201369749c97e2a639993d5668',
#                 'id': 'c492e329-852a-4afb-87b5-bbf4e99f4c57',
#                 'ignore_hash': 'False',
#                 'last_modified': '2022-11-29T11:04:57.395910',
#                 'mimetype': 'text/csv',
#                 'mimetype_inner': None,
#                 'name': 'ugz_ogd_air_h1_1984.csv',
#                 'original_url': 'https://data.integ.stadt-zuerich.ch/dataset/int_gud_ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1984.csv',
#                 'package_id': '1d82c747-bdc2-4d7a-95c7-58dc0761fff3',
#                 'position': 2,
#                 'resource_id': 'c492e329-852a-4afb-87b5-bbf4e99f4c57',
#                 'resource_type': 'file',
#                 'revision_id': '03997838-3ae9-4b8f-9f6f-0a64824c1c17',
#                 'set_url_type': 'False',
#                 'size': 3801354,
#                 'state': 'active',
#                 'task_created': '2022-10-25 08:26:54.053360',
#                 'url': 'https://data.integ.stadt-zuerich.ch/dataset/int_gud_ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1984.csv',
#                 'url_type': 'upload',
#                 'zh_hash': '8ef3cb201369749c97e2a639993d5668'},
#                {'cache_last_updated': None,
#                 'cache_url': None,
#                 'ckan_url': 'https://ckan-ogdzh-integ.clients.liip.ch',
#                 'created': '2022-10-25T08:26:54.230487',
#                 'datastore_active': True,
#                 'datastore_contains_all_records_of_source_file': 'True',
#                 'description': '',
#                 'format': 'CSV',
#                 'hash': '86961041a59991a93f9af9f3f4478e21',
#                 'id': '6dcd4647-cf38-4a1d-8737-738d6059680e',
#                 'ignore_hash': 'False',
#                 'last_modified': '2022-11-29T11:04:58.625853',
#                 'mimetype': 'text/csv',
#                 'mimetype_inner': None,
#                 'name': 'ugz_ogd_air_h1_1985.csv',
#                 'original_url': 'https://data.integ.stadt-zuerich.ch/dataset/int_gud_ugz_luftschadstoffmessung_stundenwerte/download/ugz_ogd_air_h1_1985.csv',
#                 'package_id': '1d82c747-bdc2-4d7a-95c7-58dc0761fff3',
#                 'position': 3,
#                 'resource_id': '6dcd4647-cf38-4a1d-8737-738d6059680e',
#                 'resource_type': 'file',
#                 'revision_id': '9e7ebe1f-a045-4621-983a-077ebd239c14',
#                 'set_url_type': 'False',
# ...
#  'id': 'c557b207-00ca-4b2c-8c8b-9cd5bab50557',
#  'isopen': True,
#  'legalInformation': '',
#  'license_id': 'cc-zero',
#  'license_title': 'Creative Commons CCZero',
#  'license_url': 'http://www.opendefinition.org/licenses/cc-zero',
#  'maintainer': 'Open Data Zürich',
#  'maintainer_email': 'opendata@zuerich.ch',
#  'metadata_created': '2022-11-23T22:50:50.839316',
#  'metadata_modified': '2022-11-28T23:30:55.777539',
#  'name': 'int_dwh_bev_bestand_jahr_quartier_alter_herkunft_geschlecht_od3903',
#  'notes': '\n'
#           'Anzahl der wirtschaftlichen Wohnbevölkerung nach Statistischem '
#           'Stadtquartier, Herkunft, Geschlecht, Altersjahr, '
#           '5-Jahres-Altersgruppen und Jahr, seit 1993.\n',
#  'num_resources': 1,
#  'num_tags': 14,
#  'organization': {'approval_status': 'approved',
#                   'created': '2015-06-25T13:53:59.198168',
#                   'description': '',
#                   'id': 'stadt-zurich',
#                   'image_url': 'https://www.stadt-zuerich.ch/content/dam/stzh/portal/Deutsch/OGD/Bilder/ckan/platzhalter_org_ckan.png',
#                   'is_organization': True,
#                   'name': 'stadt-zurich',
#                   'revision_id': 'a44568fe-a837-49e1-8cbf-82a713d4c2d7',
#                   'state': 'active',
#                   'title': 'Stadt Zürich',
#                   'type': 'organization'},
#  'owner_org': 'stadt-zurich',
#  'private': False,
#  'relationships_as_object': [],
#  'relationships_as_subject': [],
#  'resources': [{'cache_last_updated': None,
#                 'cache_url': None,
#                 'created': '2022-11-23T22:50:52.637614',
#                 'datastore_active': False,
#                 'datastore_contains_all_records_of_source_file': 'False',
#                 'description': '',
#                 'format': 'CSV',
#                 'hash': '',
#                 'id': '128cf87d-2773-49f4-84f5-ec822a20ad7e',
#                 'last_modified': '2022-11-28T23:30:54.157590',
#                 'mimetype': 'text/csv',
#                 'mimetype_inner': None,
#                 'name': 'BEV390OD3903.csv',
#                 'package_id': 'c557b207-00ca-4b2c-8c8b-9cd5bab50557',
#                 'position': 0,
#                 'resource_type': 'file',
#                 'revision_id': '96b210fd-2f20-4b7f-9a75-99b83301da1a',
#                 'size': 28799140,
#                 'state': 'active',
#                 'url': 'https://data.integ.stadt-zuerich.ch/dataset/int_dwh_bev_bestand_jahr_quartier_alter_herkunft_geschlecht_od3903/download/BEV390OD3903.csv',
#                 'url_type': 'upload',
#                 'zh_hash': '191337e74d8836b4640363a1af57aaa8'}],
#  'revision_id': 'eaf9db4f-67e1-4fbd-ba56-5501d6cbea1d',
#  'spatialRelationship': 'Stadt Zürich',
#  'sszBemerkungen': '**Hinweis:**\n'
#                    '\n'
#                    ' Link zu den Geodaten [**Statistische '
#                    'Stadtquartiere**](https://data.stadt-zuerich.ch/dataset/geo_statistische_quartiere).\n'
#                    '\n'
#                    '[]()\n'
#                    '\n',
#  'sszFields': '[["Ereignisjahr (technisch: StichtagDatJahr)", "Jahr"], '
#               '["Stadtquartier (Sort) (technisch: QuarSort)", "Offizielle ID '
#               'des Statistischen Stadtquartiers (Numerisch, 8 Zeichen lang)"], '
#               '["Stadtquartier (Code) (technisch: QuarCd)", "Offizielle ID des '
#               'Statistischen Stadtquartiers  (CHAR, mit f\\u00fchrender 0 bei '
#               'zweistelligen Codes, 200 Zeichen lang)"], ["Stadtquartier '
#               '(lang) (technisch: QuarLang)", "Name des Statistischen '
#               'Stadtquartiers (CHAR, 200 Zeichen lang)"], ["Vollendetes Alter '
#               '(Sort) (technisch: AlterVSort)", "Sortierschl\\u00fcssel des '
#               'vollendeten Altersjahrs einer Person bei Jahresende (Numerisch, '
#               '8 Zeichen lang)"], ["Vollendetes Alter (Code) (technisch: '
#               'AlterVCd)", "Vollendetes Altersjahr einer Person bei Jahresende '
#               '(Numerisch, 8 Zeichen lang)"], ["Vollendetes Alter (kurz) '
#               '(technisch: AlterVKurz)", "Vollendetes Altersjahr einer Person '
#               'bei Jahresende (CHAR)"], ["Vollendetes Alter 5 (Sort) '
#               '(technisch: AlterV05Sort)", "Sortierungsschl\\u00fcssel '
#               'f\\u00fcr die 5-Jahres-Altersgruppen (Numerisch, 8 Zeichen '
#               'lang)"], ["Vollendetes Alter 5 (kurz) (technisch: '
#               'AlterV05Kurz)", "5-Jahres-Altersgruppen (CHAR). Werte: 0-4, '
#               '5-9, 10-14, 15-19, etc."], ["Herkunft (lang) (technisch: '
#               'HerkunftLang)", "Bezeichnung der Herkunft einer Person (CHAR). '
#               'Unterscheidung von Schweizer Staatsb\\u00fcrgerinnen und '
#               'Staatsb\\u00fcrgern sowie Ausl\\u00e4nderinnen und '
#               'Ausl\\u00e4ndern."], ["Herkunft (Code) (technisch: '
#               'HerkunftCd)", "Code der Herkunft einer Person. Werte: 1 '
#               '(Schweiz), 2 (Ausland); (CHAR)"], ["Herkunft (Sort) (technisch: '
#               'HerkunftSort)", "Sortierungscode der Herkunft einer Person. '
#               'Werte: 1 (Schweiz), 2 (Ausland)."], ["Geschlecht (Code) '
#               '(technisch: SexCd)", "Code des Geschlechts der Person. Werte: 1 '
#               '(m\\u00e4nnlich), 2 (weiblich)"], ["Geschlecht (kurz) '
#               '(technisch: SexKurz)", "Kurzbezeichnung des Geschlechts der '
#               'Person (CHAR). Werte: M, W."], ["wirtschaftliche '
#               'Bev\\u00f6lkerung (technisch: AnzBestWir)", "Anzal Personen aus '
#               'der wirtschaftlichen Wohnbev\\u00f6lkerung"]]',
#  'state': 'active',
#  'tags': [{'display_name': 'alter',
#            'id': 'd5d657f7-6ac1-4b59-957c-159a5e29ea6f',
#            'name': 'alter',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'bevolkerungsbestand',
#            'id': 'fb70300d-499c-4037-962d-ce98a2f1dd52',
#            'name': 'bevolkerungsbestand',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'bevolkerungspyramide',
#            'id': 'e9cbb03b-6067-4e1f-93b6-37f6e4a854df',
#            'name': 'bevolkerungspyramide',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'bevszenarieninput',
#            'id': 'baf55631-bac3-4b5b-9f02-1c2e078da138',
#            'name': 'bevszenarieninput',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'demographie',
#            'id': 'bb1f725a-240f-4f0f-836b-0e7381b276a6',
#            'name': 'demographie',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'geschlecht',
#            'id': 'fe848381-3f4d-448a-9c9e-79cf3ebea423',
#            'name': 'geschlecht',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'herkunft',
#            'id': '7b802c63-119d-4ee0-8736-311303448fa1',
#            'name': 'herkunft',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'quartier',
#            'id': 'a434837a-42cb-4629-95a3-978aac6be146',
#            'name': 'quartier',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'sachdaten',
#            'id': '693d1584-be71-4808-bef8-9fa2f7c12883',
#            'name': 'sachdaten',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'sasa',
#            'id': '443557a8-212a-42fa-8f2a-fa064ac7ad9c',
#            'name': 'sasa',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'tabelle',
#            'id': 'dd8ce140-4d66-4bac-b3ba-9674c839ee7e',
#            'name': 'tabelle',
#            'state': 'active',
#            'vocabulary_id': None},
#           {'display_name': 'zeitreihe',
#            'id': '5d73d4cc-2593-4b5d-9809-1a8bfe630958',
#            'name': 'zeitreihe',
#            'state': 'active',
#            'vocabulary_id': None}],
#  'timeRange': '1993-2021',
#  'title': 'Bevölkerung nach Stadtquartier, Herkunft, Geschlecht und Alter, '
#           'seit 1993',
#  'type': 'dataset',
#  'updateInterval': ['jaehrlich'],
#  'url': 'Statistik Stadt Zürich, Präsidialdepartement',
#  'version': '1.0'}
# c:\Users\sszods\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'proxy.szh.loc'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [{'author': 'Dienstabteilung Verkehr, Sicherheitsdepartement',
#   'dataset_name': 'int_dwh_sid_dav_verkehrszaehlung_miv_od2031',
#   'dataset_title': 'Daten der Verkehrszählung zum motorisierten Individualverkehr (Stundenwerte), seit 2012',
#   'ckan_attributes': '["MSID", "MSName", "ZSID", "ZSName", "Achse", "HNr", "Hoehe", "EKoord", "NKoord", "Richtung", "Knummer", "Kname", "AnzDetektoren", "D1ID", "D2ID", "D3ID", "D4ID", "MessungDatZeit", "LieferDat", "AnzFahrzeuge", "AnzFahrzeugeStatus"]',
#   'csv_attributes': '["MSID", "MSName", "ZSID", "ZSName", "Achse", "HNr", "Hoehe", "EKoord", "NKoord", "Richtung", "Knummer", "Kname", "AnzDetektoren", "D1ID", "D2ID", "D3ID", "D4ID", "MessungDatZeit", "LieferDat", "AnzFahrzeuge", "AnzFahrzeugeStatus"]'},
#  {'author': 'Bevölkerungsamt, Präsidialdepartement',
#   'dataset_name': 'int_dwh_bev_monat_bestand_quartier_geschl_ag_herkunft_od3250',
#   'dataset_title': 'Bevölkerung nach Monat, Stadtquartier, Geschlecht, Altersgruppe und Herkunft, seit 1998',
#   'ckan_attributes': '["StichtagDatJahr", "StichtagDatMM", "StichtagDatMonat", "StichtagDat", "SexCd", "SexLang", "AlterV20Sort", "AlterV20Kurz", "HerkunftCd", "HerkunftLang", "KreisCd", "KreisLang", "QuarCd", "QuarLang", "DatenstandCd", "DatenstandLang", "AnzBestWir"]',
#   'csv_attributes': '["StichtagDatJahr", "StichtagDatMM", "StichtagDatMonat", "StichtagDat", "SexCd", "SexLang", "AlterV20Sort", "AlterV20Kurz", "HerkunftCd", "HerkunftLang", "KreisCd", "KreisLang", "QuarCd", "QuarLang", "DatenstandCd", "DatenstandLang", "AnzBestWir"]'},
#  {'author': 'Beschäftigtenstatistik, Bundesamt für Statistik',
#   'dataset_name': 'int_dwh_bfs_wir_besch_sektor_geschlecht_beschgrad_vzaeq_jahr_od4002',
#   'dataset_title': 'Beschäftigte nach Sektor, Geschlecht und Beschäftigungsgrad, Vollzeitäquivalente, seit Q2 2003',
#   'ckan_attributes': '["Jahr", "Quartal", "stzh_tot", "stzh_frau", "stzh_mann", "stzh_s2", "stzh_s3", "stzh_TZB_tot", "stzh_TZB_Frauen", "stzh_TZB_Maenner", "stzh_TZB_s2", "stzh_TZB_s3", "stzh_VZA_tot", "stzh_VZA_Frauen", "stzh_VZA_Maenner", "stzh_VZA_s2", "stzh_VZA_s3", "stzh_VZB_tot", "stzh_VZB_Frauen", "stzh_VZB_Maenner", "stzh_VZB_s2", "stzh_VZB_s3", "zh_tot", "zh_s2", "zh_s3", "ch_tot", "ch_s2", "ch_s3"]',
#   'csv_attributes': '["Jahr", "Quartal", "stzh_tot", "stzh_frau", "stzh_mann", "stzh_s2", "stzh_s3", "stzh_TZB_tot", "stzh_TZB_Frauen", "stzh_TZB_Maenner", "stzh_TZB_s2", "stzh_TZB_s3", "stzh_VZA_tot", "stzh_VZA_Frauen", "stzh_VZA_Maenner", "stzh_VZA_s2", "stzh_VZA_s3", "stzh_VZB_tot", "stzh_VZB_Frauen", "stzh_VZB_Maenner", "stzh_VZB_s2", "stzh_VZB_s3", "zh_tot", "zh_s2", "zh_s3", "ch_tot", "ch_s2", "ch_s3"]'},
#  {'author': 'Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- und Umweltdepartement',
#   'dataset_name': 'int_gud_ugz_luftschadstoffmessung_stundenwerte',
#   'dataset_title': 'Stündlich aktualisierte Luftqualitätsmessungen, seit 1983',
#   'ckan_attributes': '["Datum", "Standort", "Parameter", "Intervall", "Einheit", "Wert", "Status"]',
#   'csv_attributes': '["Datum", "Standort", "Parameter", "Intervall", "Einheit", "Wert", "Status"]'},
#  {'author': 'Messung Luftqualität, Umwelt- und Gesundheitsschutz, Gesundheits- und Umweltdepartement',
#   'dataset_name': 'int_gud_ugz_meteodaten_stundenmittelwerte',
#   'dataset_title': 'Stündlich aktualisierte Meteodaten, seit 1992',
#   'ckan_attributes': '["Datum", "Standort", "Parameter", "Intervall", "Einheit", "Wert", "Status"]',
#   'csv_attributes': '["Datum", "Standort", "Parameter", "Intervall", "Einheit", "Wert", "Status"]'},
#  {'author': 'Dienstabteilung Verkehr, Sicherheitsdepartement',
#   'dataset_name': 'sid_dav_verkehrszaehlung_miv_od2031',
#   'dataset_title': 'Daten der Verkehrszählung zum motorisierten Individualverkehr (Stundenwerte), seit 2012',
#   'ckan_attributes': '["MSID", "MSName", "ZSID", "ZSName", "Achse", "HNr", "Hoehe", "EKoord", "NKoord", "Richtung", "Knummer", "Kname", "AnzDetektoren", "D1ID", "D2ID", "D3ID", "D4ID", "MessungDatZeit", "LieferDat", "AnzFahrzeuge", "AnzFahrzeugeStatus"]',
#   'csv_attributes': '["MSID", "MSName", "ZSID", "ZSName", "Achse", "HNr", "Hoehe", "EKoord", "NKoord", "Richtung", "Knummer", "Kname", "AnzDetektoren", "D1ID", "D2ID", "D3ID", "D4ID", "MessungDatZeit", "LieferDat", "AnzFahrzeuge", "AnzFahrzeugeStatus"]'},
#  {'author': 'Bevölkerungsamt, Präsidialdepartement',
#   'dataset_name': 'int_dwh_bev_tag_geburten_quartier_geschl_ag_herkunft_od4031',
#   'dataset_title': 'Geburten nach Tag, Stadtquartier, Geschlecht und Herkunft, seit 1998',
#   'ckan_attributes': '["GueltigAbDatJahr", "GueltigAbDatMM", "GueltigAbDatDD", "GueltigAbDat", "SexCd", "SexLang", "HerkunftCd", "HerkunftLang", "KreisCd", "KreisLang", "QuarCd", "QuarLang", "DatenstandCd", "DatenstandLang", "AnzGebuWir"]',
#   'csv_attributes': '["GueltigAbDatJahr", "GueltigAbDatMM", "GueltigAbDatDD", "GueltigAbDat", "SexCd", "SexLang", "HerkunftCd", "HerkunftLang", "KreisCd", "KreisLang", "QuarCd", "QuarLang", "DatenstandCd", "DatenstandLang", "AnzGebuWir"]'},
#  {'author': 'Beschäftigtenstatistik, Bundesamt für Statistik',
#   'dataset_name': 'bfs_wir_besch_sektor_geschlecht_beschgrad_vzaeq_jahr_od4002',
#   'dataset_title': 'Beschäftigte nach Sektor, Geschlecht und Beschäftigungsgrad, Vollzeitäquivalente, seit Q2 2003',
#   'ckan_attributes': '["Jahr", "Quartal", "stzh_tot", "stzh_frau", "stzh_mann", "stzh_s2", "stzh_s3", "stzh_TZB_tot", "stzh_TZB_Frauen", "stzh_TZB_Maenner", "stzh_TZB_s2", "stzh_TZB_s3", "stzh_VZA_tot", "stzh_VZA_Frauen", "stzh_VZA_Maenner", "stzh_VZA_s2", "stzh_VZA_s3", "stzh_VZB_tot", "stzh_VZB_Frauen", "stzh_VZB_Maenner", "stzh_VZB_s2", "stzh_VZB_s3", "zh_tot", "zh_s2", "zh_s3", "ch_tot", "ch_s2", "ch_s3"]',
#   'csv_attributes': '["Jahr", "Quartal", "stzh_tot", "stzh_frau", "stzh_mann", "stzh_s2", "stzh_s3", "stzh_TZB_tot", "stzh_TZB_Frauen", "stzh_TZB_Maenner", "stzh_TZB_s2", "stzh_TZB_s3", "stzh_VZA_tot", "stzh_VZA_Frauen", "stzh_VZA_Maenner", "stzh_VZA_s2", "stzh_VZA_s3", "stzh_VZB_tot", "stzh_VZB_Frauen", "stzh_VZB_Maenner", "stzh_VZB_s2", "stzh_VZB_s3", "zh_tot", "zh_s2", "zh_s3", "ch_tot", "ch_s2", "ch_s3"]'},
#  {'author': 'Bevölkerungsamt, Präsidialdepartement',
#   'dataset_name': 'int_dwh_bev_monat_geburten_quartier_geschl_ag_herkunft_od4030',
#   'dataset_title': 'Geburten nach Monat, Stadtquartier, Geschlecht und Herkunft, seit 1998',
#   'ckan_attributes': '["EreignisDatJahr", "EreignisDatMM", "EreignisDatMonat", "StichtagDat", "SexCd", "SexLang", "HerkunftCd", "HerkunftLang", "KreisCd", "KreisLang", "QuarCd", "QuarLang", "DatenstandCd", "DatenstandLang", "AnzGebuWir"]',
#   'csv_attributes': '["EreignisDatJahr", "EreignisDatMM", "EreignisDatMonat", "StichtagDat", "SexCd", "SexLang", "HerkunftCd", "HerkunftLang", "KreisCd", "KreisLang", "QuarCd", "QuarLang", "DatenstandCd", "DatenstandLang", "AnzGebuWir"]'},
#  {'author': 'Bevölkerungsamt, Präsidialdepartement',
#   'dataset_name': 'int_dwh_bev_bestand_jahr_quartier_alter_herkunft_geschlecht_od3903',
#   'dataset_title': 'Bevölkerung nach Stadtquartier, Herkunft, Geschlecht und Alter, seit 1993',
#   'ckan_attributes': '["StichtagDatJahr", "QuarSort", "QuarCd", "QuarLang", "AlterVSort", "AlterVCd", "AlterVKurz", "AlterV05Sort", "AlterV05Kurz", "HerkunftLang", "HerkunftCd", "HerkunftSort", "SexCd", "SexKurz", "AnzBestWir"]',
#   'csv_attributes': '["StichtagDatJahr", "QuarSort", "QuarCd", "QuarLang", "AlterVSort", "AlterVCd", "AlterVKurz", "AlterV05Sort", "AlterV05Kurz", "HerkunftLang", "HerkunftCd", "HerkunftSort", "SexCd", "SexKurz", "AnzBestWir"]'}]

# %%
csv_path = os.path.join(__location__, 'ckan_attributes.csv')

with open(csv_path, 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(
        f,
        list(rows[0].keys()),
        delimiter=',',
        quotechar='"',
        lineterminator='\n',
        quoting=csv.QUOTE_MINIMAL
    )
    writer.writeheader()
    writer.writerows(rows)

# %%
with open(csv_path, 'r', newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        csv_attr = json.loads(row['csv_attributes'])
        ckan_attr = json.loads(row['ckan_attributes'])
        csv_attr.sort()
        ckan_attr.sort()

        #ckan_attr.pop()
        #ckan_attr.pop()

        diff = diff_strings(",".join(csv_attr), ",".join(ckan_attr))
        if diff:
            print(diff)
            print(",".join(csv_attr))
            print(",".join(ckan_attr))
        else:
            print("No diff.")
# Out:
# No diff.
# No diff.
# No diff.
# No diff.
# No diff.
# No diff.
# No diff.
# Jahr,Quartal,ch_s2,ch_s3,ch_tot,stzh_TZB_Frauen,stzh_TZB_Maenner,stzh_TZB_s2,stzh_TZB_s3,stzh_TZB_tot,stzh_VZA_Frauen,stzh_VZA_Maenner,stzh_VZA_s2,stzh_VZA_s3,stzh_VZA_tot,stzh_VZB_Frauen,stzh_VZB_Maenner,stzh_VZB_s2,stzh_VZB_s3,stzh_VZB_tot,stzh_frau,stzh_mann,stzh_s2,stzh_s3,stzh_tot,zh_s2,zh_s3,zh_tot
# Jahr,Quartal,ch_s2,ch_tot,stzh_TZB_Frauen,stzh_TZB_Maenner,stzh_TZB_s2,stzh_TZB_s3,stzh_TZB_tot,stzh_VZA_Frauen,stzh_VZA_Maenner,stzh_VZA_s2,stzh_VZA_s3,stzh_VZA_tot,stzh_VZB_Frauen,stzh_VZB_Maenner,stzh_VZB_s2,stzh_VZB_s3,stzh_VZB_tot,stzh_frau,stzh_mann,stzh_s2,stzh_s3,stzh_tot,zh_s2,zh_s3,zh_tot
# Jahr,Quartal,ch_s2,ch_s3,ch_tot,stzh_TZB_Frauen,stzh_TZB_Maenner,stzh_TZB_s2,stzh_TZB_s3,stzh_TZB_tot,stzh_VZA_Frauen,stzh_VZA_Maenner,stzh_VZA_s2,stzh_VZA_s3,stzh_VZA_tot,stzh_VZB_Frauen,stzh_VZB_Maenner,stzh_VZB_s2,stzh_VZB_s3,stzh_VZB_tot,stzh_frau,stzh_mann,stzh_s2,stzh_s3,stzh_tot,zh_s2,zh_s3,zh_tot
# No diff.
# No diff.

# %%
# download last file from GitHub and compare with today
